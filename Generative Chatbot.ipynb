# %%
# Import modules
import re

# Load the datasets
dataset = "human_text.txt"
dataset2 = "robot_text.txt"

# Opening the files and reading them
with open(dataset, 'r', encoding = 'utf-8') as f:
  questions = f.read().split('\n')
with open(dataset2, 'r', encoding = 'utf-8') as f:
  answers = f.read().split('\n')

# Removing the brackets and the text inside the brackets and then replacing them with the word hi
questions = [re.sub("[\(\[].*?[\)\]]", "hi", line) for line in questions]
# Removing all the punctuation from the questions.
questions = [" ".join(re.findall(r"\w+", line)) for line in questions]
answers = [re.sub("[\(\[].*?[\)\]]", "hi", line) for line in answers]
answers = [" ".join(re.findall(r"\w+", line)) for line in answers]

# Zipping the questions and answers together.
pairs = list(zip(questions, answers))

# %%
# Import modules
import numpy as np
import re

# Adapted from https://keras.io/examples/nlp/lstm_seq2seq/

# Creating empty lists to store the sentences
input_texts = []
target_texts = []
# Creating empty vocabulary sets
input_characters = set()
target_characters = set()

# Creating a list of the first 400 lines of the pairs list
for line in pairs[:400]:
  # Assigning the first and second elements of the list to the variables `input_text` and `target_text`
  input_text, target_text = line[0], line[1]
  # Adding the input text to the input_texts list
  input_texts.append(input_text)
  # Splitting the target text into words and adding a space between each word
  target_text = " ".join(re.findall(r"[\w']+|[^\s\w]", target_text))
  # Adding the start and end tags to the target text
  target_text = '<START> ' + target_text + ' <END>'
  # Adding the target text to the target_texts list
  target_texts.append(target_text)
  
  # Creating a list of unique words for the input and output sentences
  for char in re.findall(r"[\w']+|[^\s\w]", input_text):
    if char not in input_characters:
      input_characters.add(char)
  # Splitting the target text into words and adding a space between each word.
  for char in target_text.split():
    if char not in target_characters:
      target_characters.add(char)

# Sorting the list of unique words in the input and output sentences
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
# Counting the number of unique words in the input and target text.
num_encoder_characters = len(input_characters)
num_decoder_characters = len(target_characters)

# Creating a dictionary of the input and output words and their index.
input_features_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_features_index = dict([(char, i) for i, char in enumerate(target_characters)])

# Store the input characters as key-value pairs but this time they are swapped where word = index & value = key
# Is reversed to decode back to a readable format
reverse_input_features_index = dict((i, char) for char, i in input_features_index.items())
reverse_target_features_index = dict((i, char) for char, i in target_features_index.items())

# Finding the maximum length of the input and output sentences
max_encoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", input_text)) for input_text in input_texts])
max_decoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", target_text)) for target_text in target_texts])

# Prints to the console what is being fed to the model
print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_characters)
print("Number of unique output tokens:", num_decoder_characters)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)


# Creating a 3D array of zeros with the dimensions of the number of input texts, the maximum length of
# the input text and the number of unique words in the input text
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_characters), dtype='float32')
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_characters), dtype='float32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_characters), dtype='float32')

# For loop to fill out the 1s in each vector
# Iterating through the input and target texts and assigning them to the `input_text` and `target_text`
for line, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for timestep, char in enumerate(re.findall(r"[\w']+|[^\s\w]", input_text)):
        # Assigns a value of 1 for the current word, timestep and line 
        encoder_input_data[line, timestep, input_features_index[char]] = 1.0
    
    # Same method applied to the decoder
    # Is creating a one-hot encoded vector for each word in the target text
    for timestep, char in enumerate(target_text.split()):
        decoder_input_data[line, timestep, target_features_index[char]] = 1.0
        # But if the timestep is not 0 then decreases it by 1
        if timestep > 0:
            decoder_target_data[line, timestep - 1, target_features_index[char]] = 1.0
# Out:
# Number of samples: 400
# Number of unique input tokens: 981
# Number of unique output tokens: 1001
# Max sequence length for inputs: 51
# Max sequence length for outputs: 50

# %%
# Import modules
from tensorflow import keras
from keras.layers import Input, LSTM, Dense, Dropout
from keras.models import Model

# Adapted from https://keras.io/examples/nlp/lstm_seq2seq/

# Number of units in the LSTM layer
dimensionality = 256
# Number of samples per gradient update
batch_size = 10
# Number of times the model is exposed to the training dataset
epochs = 4600

# Encoder Training
# Defining the input layer of the encoder
encoder_inputs = Input(shape = (None, num_encoder_characters))
# Creating a LSTM layer with 256 units and returning the hidden state and cell state
encoder_lstm = LSTM(dimensionality, return_state = True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(encoder_inputs)
# Creating a list of the hidden state and cell state of the encoder
encoder_states = [state_hidden, state_cell]

# Decoder Training
# Defining the input layer of the decoder
decoder_inputs = Input(shape = (None, num_decoder_characters))
# Creating a LSTM layer with 256 units and returning the hidden state and cell state
decoder_lstm = LSTM(dimensionality, return_sequences = True, return_state = True)
# The decoder LSTM layer is taking the decoder input data and the encoder states as input. The encoder
# states are the hidden state and cell state of the encoder LSTM layer. The decoder LSTM layer is
# returning the decoder outputs, the hidden state and cell state of the decoder LSTM layer.
decoder_outputs, decoder_state_hidden, decoder_state_cell = decoder_lstm(decoder_inputs, initial_state = encoder_states)
# A regularization technique that randomly sets half of the input units to 0 at each update during
# training time, which helps prevent overfitting
dropout = Dropout(rate = 0.5)
# Applying the dropout regularization technique to the decoder outputs
decoder_outputs = dropout(decoder_outputs)
# Creating a dense layer with the number of decoder characters as the number of units and the
# activation function as softmax
decoder_dense = Dense(num_decoder_characters, activation = 'softmax')
# Applying the dense layer to the decoder outputs
decoder_outputs = decoder_dense(decoder_outputs)

# Model
# Creating a model with the encoder inputs and decoder inputs as the input layers and the decoder
# outputs as the output layer.
training_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
# The `compile` method is used to configure the model for training. The `optimizer` parameter is used
# to specify the optimizer to be used for training. The `loss` parameter is used to specify the loss
# function to be used for training. The `metrics` parameter is used to specify the metrics to be used
# for training. The `sample_weight_mode` parameter is used to specify the sample weight mode to be
# used for training.
training_model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'], sample_weight_mode = 'temporal')
# The `fit` method is used to train the model. The `encoder_input_data` and `decoder_input_data` are
# the input data for the encoder and decoder. The `decoder_target_data` is the target
# data for the decoder. The `batch_size` is the number of samples per gradient update. The `epochs` is
# the number of times the model is exposed to the training dataset. The `validation_split` is the
# fraction of the training data to be used as validation data.
training_model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size = batch_size, epochs = epochs, validation_split = 0.2)
# Saving the model to a file
training_model.save('training_model.h5')
# Out:
# Streaming output truncated to the last 5000 lines.
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3398 - accuracy: 0.1479 - val_loss: 1.9062 - val_accuracy: 0.0207
# Epoch 2102/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3363 - accuracy: 0.1487 - val_loss: 1.9045 - val_accuracy: 0.0217
# Epoch 2103/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3396 - accuracy: 0.1464 - val_loss: 1.9040 - val_accuracy: 0.0210
# Epoch 2104/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3389 - accuracy: 0.1480 - val_loss: 1.8973 - val_accuracy: 0.0213
# Epoch 2105/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3388 - accuracy: 0.1477 - val_loss: 1.9163 - val_accuracy: 0.0210
# Epoch 2106/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3384 - accuracy: 0.1484 - val_loss: 1.9120 - val_accuracy: 0.0200
# Epoch 2107/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3407 - accuracy: 0.1493 - val_loss: 1.9050 - val_accuracy: 0.0205
# Epoch 2108/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3436 - accuracy: 0.1466 - val_loss: 1.9158 - val_accuracy: 0.0207
# Epoch 2109/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3440 - accuracy: 0.1471 - val_loss: 1.9110 - val_accuracy: 0.0210
# Epoch 2110/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3381 - accuracy: 0.1482 - val_loss: 1.9201 - val_accuracy: 0.0200
# Epoch 2111/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3356 - accuracy: 0.1478 - val_loss: 1.9311 - val_accuracy: 0.0205
# Epoch 2112/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3409 - accuracy: 0.1475 - val_loss: 1.9289 - val_accuracy: 0.0210
# Epoch 2113/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.3303 - accuracy: 0.1497 - val_loss: 1.9169 - val_accuracy: 0.0207
# Epoch 2114/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3358 - accuracy: 0.1488 - val_loss: 1.9032 - val_accuracy: 0.0210
# Epoch 2115/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3366 - accuracy: 0.1476 - val_loss: 1.9012 - val_accuracy: 0.0207
# Epoch 2116/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3274 - accuracy: 0.1504 - val_loss: 1.9089 - val_accuracy: 0.0207
# Epoch 2117/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3369 - accuracy: 0.1486 - val_loss: 1.9109 - val_accuracy: 0.0205
# Epoch 2118/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3294 - accuracy: 0.1486 - val_loss: 1.9083 - val_accuracy: 0.0195
# Epoch 2119/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3314 - accuracy: 0.1494 - val_loss: 1.8987 - val_accuracy: 0.0207
# Epoch 2120/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3320 - accuracy: 0.1493 - val_loss: 1.9035 - val_accuracy: 0.0213
# Epoch 2121/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3265 - accuracy: 0.1497 - val_loss: 1.9211 - val_accuracy: 0.0213
# Epoch 2122/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3361 - accuracy: 0.1476 - val_loss: 1.9061 - val_accuracy: 0.0205
# Epoch 2123/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3403 - accuracy: 0.1462 - val_loss: 1.9099 - val_accuracy: 0.0200
# Epoch 2124/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3354 - accuracy: 0.1477 - val_loss: 1.9252 - val_accuracy: 0.0205
# Epoch 2125/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3384 - accuracy: 0.1490 - val_loss: 1.9108 - val_accuracy: 0.0205
# Epoch 2126/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3367 - accuracy: 0.1471 - val_loss: 1.8982 - val_accuracy: 0.0227
# Epoch 2127/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3348 - accuracy: 0.1478 - val_loss: 1.9028 - val_accuracy: 0.0220
# Epoch 2128/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3315 - accuracy: 0.1497 - val_loss: 1.9212 - val_accuracy: 0.0213
# Epoch 2129/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3332 - accuracy: 0.1495 - val_loss: 1.9191 - val_accuracy: 0.0217
# Epoch 2130/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3447 - accuracy: 0.1478 - val_loss: 1.9229 - val_accuracy: 0.0225
# Epoch 2131/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3346 - accuracy: 0.1488 - val_loss: 1.9206 - val_accuracy: 0.0215
# Epoch 2132/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3281 - accuracy: 0.1506 - val_loss: 1.9183 - val_accuracy: 0.0213
# Epoch 2133/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3333 - accuracy: 0.1491 - val_loss: 1.9263 - val_accuracy: 0.0210
# Epoch 2134/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3282 - accuracy: 0.1478 - val_loss: 1.9250 - val_accuracy: 0.0200
# Epoch 2135/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3243 - accuracy: 0.1503 - val_loss: 1.9131 - val_accuracy: 0.0198
# Epoch 2136/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3278 - accuracy: 0.1503 - val_loss: 1.9126 - val_accuracy: 0.0210
# Epoch 2137/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3320 - accuracy: 0.1481 - val_loss: 1.9172 - val_accuracy: 0.0217
# Epoch 2138/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3308 - accuracy: 0.1499 - val_loss: 1.9235 - val_accuracy: 0.0215
# Epoch 2139/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3415 - accuracy: 0.1483 - val_loss: 1.9071 - val_accuracy: 0.0220
# Epoch 2140/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3270 - accuracy: 0.1486 - val_loss: 1.9230 - val_accuracy: 0.0213
# Epoch 2141/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3309 - accuracy: 0.1482 - val_loss: 1.8932 - val_accuracy: 0.0213
# Epoch 2142/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3322 - accuracy: 0.1488 - val_loss: 1.9093 - val_accuracy: 0.0223
# Epoch 2143/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3336 - accuracy: 0.1482 - val_loss: 1.9051 - val_accuracy: 0.0207
# Epoch 2144/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3338 - accuracy: 0.1465 - val_loss: 1.9044 - val_accuracy: 0.0215
# Epoch 2145/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3205 - accuracy: 0.1519 - val_loss: 1.9101 - val_accuracy: 0.0207
# Epoch 2146/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3225 - accuracy: 0.1513 - val_loss: 1.9181 - val_accuracy: 0.0215
# Epoch 2147/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3243 - accuracy: 0.1504 - val_loss: 1.9066 - val_accuracy: 0.0215
# Epoch 2148/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3271 - accuracy: 0.1509 - val_loss: 1.9138 - val_accuracy: 0.0207
# Epoch 2149/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3266 - accuracy: 0.1494 - val_loss: 1.9086 - val_accuracy: 0.0215
# Epoch 2150/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3301 - accuracy: 0.1496 - val_loss: 1.8988 - val_accuracy: 0.0210
# Epoch 2151/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3289 - accuracy: 0.1488 - val_loss: 1.8998 - val_accuracy: 0.0207
# Epoch 2152/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3264 - accuracy: 0.1495 - val_loss: 1.9161 - val_accuracy: 0.0217
# Epoch 2153/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3260 - accuracy: 0.1503 - val_loss: 1.9172 - val_accuracy: 0.0223
# Epoch 2154/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3239 - accuracy: 0.1501 - val_loss: 1.9047 - val_accuracy: 0.0210
# Epoch 2155/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3257 - accuracy: 0.1501 - val_loss: 1.9097 - val_accuracy: 0.0213
# Epoch 2156/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3290 - accuracy: 0.1494 - val_loss: 1.9061 - val_accuracy: 0.0217
# Epoch 2157/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3243 - accuracy: 0.1492 - val_loss: 1.8979 - val_accuracy: 0.0213
# Epoch 2158/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3313 - accuracy: 0.1484 - val_loss: 1.8989 - val_accuracy: 0.0225
# Epoch 2159/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3259 - accuracy: 0.1490 - val_loss: 1.9118 - val_accuracy: 0.0217
# Epoch 2160/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3338 - accuracy: 0.1488 - val_loss: 1.8948 - val_accuracy: 0.0223
# Epoch 2161/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3214 - accuracy: 0.1529 - val_loss: 1.9065 - val_accuracy: 0.0223
# Epoch 2162/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3188 - accuracy: 0.1500 - val_loss: 1.8972 - val_accuracy: 0.0223
# Epoch 2163/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3232 - accuracy: 0.1494 - val_loss: 1.9099 - val_accuracy: 0.0203
# Epoch 2164/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3272 - accuracy: 0.1504 - val_loss: 1.9140 - val_accuracy: 0.0207
# Epoch 2165/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3262 - accuracy: 0.1482 - val_loss: 1.8939 - val_accuracy: 0.0213
# Epoch 2166/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3239 - accuracy: 0.1507 - val_loss: 1.9039 - val_accuracy: 0.0215
# Epoch 2167/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3213 - accuracy: 0.1507 - val_loss: 1.9084 - val_accuracy: 0.0217
# Epoch 2168/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3243 - accuracy: 0.1515 - val_loss: 1.9369 - val_accuracy: 0.0213
# Epoch 2169/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3210 - accuracy: 0.1511 - val_loss: 1.9160 - val_accuracy: 0.0215
# Epoch 2170/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3268 - accuracy: 0.1497 - val_loss: 1.9046 - val_accuracy: 0.0210
# Epoch 2171/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3284 - accuracy: 0.1492 - val_loss: 1.9131 - val_accuracy: 0.0217
# Epoch 2172/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.3205 - accuracy: 0.1511 - val_loss: 1.8994 - val_accuracy: 0.0215
# Epoch 2173/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3276 - accuracy: 0.1483 - val_loss: 1.8985 - val_accuracy: 0.0217
# Epoch 2174/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3188 - accuracy: 0.1521 - val_loss: 1.9055 - val_accuracy: 0.0215
# Epoch 2175/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3239 - accuracy: 0.1486 - val_loss: 1.9030 - val_accuracy: 0.0215
# Epoch 2176/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3175 - accuracy: 0.1511 - val_loss: 1.9071 - val_accuracy: 0.0215
# Epoch 2177/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3210 - accuracy: 0.1506 - val_loss: 1.9012 - val_accuracy: 0.0220
# Epoch 2178/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3274 - accuracy: 0.1489 - val_loss: 1.8978 - val_accuracy: 0.0215
# Epoch 2179/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3198 - accuracy: 0.1499 - val_loss: 1.9127 - val_accuracy: 0.0207
# Epoch 2180/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3219 - accuracy: 0.1499 - val_loss: 1.8956 - val_accuracy: 0.0207
# Epoch 2181/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3220 - accuracy: 0.1499 - val_loss: 1.9091 - val_accuracy: 0.0213
# Epoch 2182/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3223 - accuracy: 0.1511 - val_loss: 1.9040 - val_accuracy: 0.0210
# Epoch 2183/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3206 - accuracy: 0.1513 - val_loss: 1.9052 - val_accuracy: 0.0205
# Epoch 2184/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3174 - accuracy: 0.1506 - val_loss: 1.9137 - val_accuracy: 0.0217
# Epoch 2185/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3160 - accuracy: 0.1506 - val_loss: 1.9116 - val_accuracy: 0.0213
# Epoch 2186/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3293 - accuracy: 0.1483 - val_loss: 1.8984 - val_accuracy: 0.0217
# Epoch 2187/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3219 - accuracy: 0.1508 - val_loss: 1.9040 - val_accuracy: 0.0220
# Epoch 2188/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3245 - accuracy: 0.1511 - val_loss: 1.9073 - val_accuracy: 0.0213
# Epoch 2189/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3239 - accuracy: 0.1500 - val_loss: 1.8797 - val_accuracy: 0.0220
# Epoch 2190/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3272 - accuracy: 0.1496 - val_loss: 1.9216 - val_accuracy: 0.0217
# Epoch 2191/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3168 - accuracy: 0.1517 - val_loss: 1.8902 - val_accuracy: 0.0220
# Epoch 2192/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3244 - accuracy: 0.1506 - val_loss: 1.8877 - val_accuracy: 0.0215
# Epoch 2193/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3277 - accuracy: 0.1501 - val_loss: 1.8859 - val_accuracy: 0.0223
# Epoch 2194/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3180 - accuracy: 0.1526 - val_loss: 1.8987 - val_accuracy: 0.0213
# Epoch 2195/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3160 - accuracy: 0.1517 - val_loss: 1.9072 - val_accuracy: 0.0215
# Epoch 2196/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3172 - accuracy: 0.1513 - val_loss: 1.8979 - val_accuracy: 0.0210
# Epoch 2197/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3178 - accuracy: 0.1519 - val_loss: 1.8980 - val_accuracy: 0.0207
# Epoch 2198/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3229 - accuracy: 0.1528 - val_loss: 1.9114 - val_accuracy: 0.0198
# Epoch 2199/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.3182 - accuracy: 0.1516 - val_loss: 1.8978 - val_accuracy: 0.0215
# Epoch 2200/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3198 - accuracy: 0.1500 - val_loss: 1.9084 - val_accuracy: 0.0217
# Epoch 2201/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3222 - accuracy: 0.1518 - val_loss: 1.9171 - val_accuracy: 0.0205
# Epoch 2202/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3185 - accuracy: 0.1503 - val_loss: 1.9150 - val_accuracy: 0.0215
# Epoch 2203/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.3154 - accuracy: 0.1513 - val_loss: 1.9038 - val_accuracy: 0.0227
# Epoch 2204/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3191 - accuracy: 0.1494 - val_loss: 1.9086 - val_accuracy: 0.0210
# Epoch 2205/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3157 - accuracy: 0.1514 - val_loss: 1.9083 - val_accuracy: 0.0233
# Epoch 2206/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3244 - accuracy: 0.1500 - val_loss: 1.9261 - val_accuracy: 0.0210
# Epoch 2207/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3188 - accuracy: 0.1523 - val_loss: 1.9104 - val_accuracy: 0.0217
# Epoch 2208/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3183 - accuracy: 0.1496 - val_loss: 1.9176 - val_accuracy: 0.0215
# Epoch 2209/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3195 - accuracy: 0.1502 - val_loss: 1.9086 - val_accuracy: 0.0213
# Epoch 2210/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.3182 - accuracy: 0.1508 - val_loss: 1.9140 - val_accuracy: 0.0200
# Epoch 2211/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3151 - accuracy: 0.1513 - val_loss: 1.9118 - val_accuracy: 0.0210
# Epoch 2212/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.3127 - accuracy: 0.1512 - val_loss: 1.9113 - val_accuracy: 0.0213
# Epoch 2213/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3169 - accuracy: 0.1509 - val_loss: 1.9165 - val_accuracy: 0.0215
# Epoch 2214/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3168 - accuracy: 0.1503 - val_loss: 1.9014 - val_accuracy: 0.0210
# Epoch 2215/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3192 - accuracy: 0.1505 - val_loss: 1.8977 - val_accuracy: 0.0207
# Epoch 2216/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3175 - accuracy: 0.1510 - val_loss: 1.8863 - val_accuracy: 0.0210
# Epoch 2217/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3150 - accuracy: 0.1509 - val_loss: 1.9080 - val_accuracy: 0.0210
# Epoch 2218/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3186 - accuracy: 0.1509 - val_loss: 1.9049 - val_accuracy: 0.0210
# Epoch 2219/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3182 - accuracy: 0.1514 - val_loss: 1.9096 - val_accuracy: 0.0210
# Epoch 2220/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3193 - accuracy: 0.1500 - val_loss: 1.9103 - val_accuracy: 0.0203
# Epoch 2221/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3167 - accuracy: 0.1501 - val_loss: 1.9102 - val_accuracy: 0.0210
# Epoch 2222/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3186 - accuracy: 0.1493 - val_loss: 1.9129 - val_accuracy: 0.0215
# Epoch 2223/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3254 - accuracy: 0.1484 - val_loss: 1.9017 - val_accuracy: 0.0207
# Epoch 2224/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3208 - accuracy: 0.1508 - val_loss: 1.9147 - val_accuracy: 0.0210
# Epoch 2225/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3164 - accuracy: 0.1512 - val_loss: 1.9117 - val_accuracy: 0.0207
# Epoch 2226/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3162 - accuracy: 0.1499 - val_loss: 1.9180 - val_accuracy: 0.0215
# Epoch 2227/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3158 - accuracy: 0.1531 - val_loss: 1.9009 - val_accuracy: 0.0215
# Epoch 2228/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3133 - accuracy: 0.1516 - val_loss: 1.9043 - val_accuracy: 0.0215
# Epoch 2229/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3193 - accuracy: 0.1505 - val_loss: 1.9029 - val_accuracy: 0.0213
# Epoch 2230/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3274 - accuracy: 0.1499 - val_loss: 1.8962 - val_accuracy: 0.0223
# Epoch 2231/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3151 - accuracy: 0.1504 - val_loss: 1.9078 - val_accuracy: 0.0207
# Epoch 2232/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3204 - accuracy: 0.1511 - val_loss: 1.9095 - val_accuracy: 0.0210
# Epoch 2233/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3214 - accuracy: 0.1508 - val_loss: 1.8916 - val_accuracy: 0.0223
# Epoch 2234/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3109 - accuracy: 0.1524 - val_loss: 1.8942 - val_accuracy: 0.0215
# Epoch 2235/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3132 - accuracy: 0.1521 - val_loss: 1.9095 - val_accuracy: 0.0205
# Epoch 2236/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3103 - accuracy: 0.1539 - val_loss: 1.9136 - val_accuracy: 0.0207
# Epoch 2237/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3224 - accuracy: 0.1509 - val_loss: 1.9297 - val_accuracy: 0.0203
# Epoch 2238/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3139 - accuracy: 0.1509 - val_loss: 1.9260 - val_accuracy: 0.0215
# Epoch 2239/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3106 - accuracy: 0.1519 - val_loss: 1.9080 - val_accuracy: 0.0215
# Epoch 2240/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3159 - accuracy: 0.1503 - val_loss: 1.9005 - val_accuracy: 0.0210
# Epoch 2241/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3103 - accuracy: 0.1517 - val_loss: 1.9090 - val_accuracy: 0.0213
# Epoch 2242/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3077 - accuracy: 0.1513 - val_loss: 1.9043 - val_accuracy: 0.0213
# Epoch 2243/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3135 - accuracy: 0.1517 - val_loss: 1.8958 - val_accuracy: 0.0210
# Epoch 2244/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3136 - accuracy: 0.1509 - val_loss: 1.9026 - val_accuracy: 0.0215
# Epoch 2245/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3143 - accuracy: 0.1496 - val_loss: 1.9017 - val_accuracy: 0.0210
# Epoch 2246/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3145 - accuracy: 0.1507 - val_loss: 1.9124 - val_accuracy: 0.0223
# Epoch 2247/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3173 - accuracy: 0.1506 - val_loss: 1.9110 - val_accuracy: 0.0207
# Epoch 2248/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3132 - accuracy: 0.1509 - val_loss: 1.9046 - val_accuracy: 0.0207
# Epoch 2249/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3147 - accuracy: 0.1510 - val_loss: 1.9139 - val_accuracy: 0.0207
# Epoch 2250/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3174 - accuracy: 0.1507 - val_loss: 1.8967 - val_accuracy: 0.0220
# Epoch 2251/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3107 - accuracy: 0.1537 - val_loss: 1.8872 - val_accuracy: 0.0210
# Epoch 2252/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3081 - accuracy: 0.1521 - val_loss: 1.9136 - val_accuracy: 0.0213
# Epoch 2253/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3113 - accuracy: 0.1524 - val_loss: 1.9098 - val_accuracy: 0.0225
# Epoch 2254/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3133 - accuracy: 0.1523 - val_loss: 1.8990 - val_accuracy: 0.0213
# Epoch 2255/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3054 - accuracy: 0.1533 - val_loss: 1.9215 - val_accuracy: 0.0215
# Epoch 2256/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3143 - accuracy: 0.1512 - val_loss: 1.9269 - val_accuracy: 0.0220
# Epoch 2257/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3134 - accuracy: 0.1514 - val_loss: 1.9335 - val_accuracy: 0.0213
# Epoch 2258/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3094 - accuracy: 0.1517 - val_loss: 1.9235 - val_accuracy: 0.0205
# Epoch 2259/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3117 - accuracy: 0.1533 - val_loss: 1.9172 - val_accuracy: 0.0207
# Epoch 2260/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3113 - accuracy: 0.1512 - val_loss: 1.9322 - val_accuracy: 0.0213
# Epoch 2261/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3161 - accuracy: 0.1517 - val_loss: 1.9314 - val_accuracy: 0.0213
# Epoch 2262/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3176 - accuracy: 0.1513 - val_loss: 1.9268 - val_accuracy: 0.0207
# Epoch 2263/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.3185 - accuracy: 0.1493 - val_loss: 1.9078 - val_accuracy: 0.0215
# Epoch 2264/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3097 - accuracy: 0.1509 - val_loss: 1.9053 - val_accuracy: 0.0207
# Epoch 2265/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3158 - accuracy: 0.1525 - val_loss: 1.9083 - val_accuracy: 0.0205
# Epoch 2266/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3190 - accuracy: 0.1511 - val_loss: 1.9303 - val_accuracy: 0.0203
# Epoch 2267/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3126 - accuracy: 0.1510 - val_loss: 1.9366 - val_accuracy: 0.0205
# Epoch 2268/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3089 - accuracy: 0.1529 - val_loss: 1.9110 - val_accuracy: 0.0217
# Epoch 2269/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3097 - accuracy: 0.1527 - val_loss: 1.9224 - val_accuracy: 0.0207
# Epoch 2270/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3163 - accuracy: 0.1522 - val_loss: 1.9066 - val_accuracy: 0.0215
# Epoch 2271/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3117 - accuracy: 0.1524 - val_loss: 1.9098 - val_accuracy: 0.0210
# Epoch 2272/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3130 - accuracy: 0.1511 - val_loss: 1.9146 - val_accuracy: 0.0217
# Epoch 2273/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3058 - accuracy: 0.1524 - val_loss: 1.9069 - val_accuracy: 0.0213
# Epoch 2274/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3099 - accuracy: 0.1514 - val_loss: 1.9127 - val_accuracy: 0.0213
# Epoch 2275/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3087 - accuracy: 0.1516 - val_loss: 1.9268 - val_accuracy: 0.0215
# Epoch 2276/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3167 - accuracy: 0.1499 - val_loss: 1.9116 - val_accuracy: 0.0220
# Epoch 2277/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3055 - accuracy: 0.1532 - val_loss: 1.9049 - val_accuracy: 0.0205
# Epoch 2278/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3112 - accuracy: 0.1512 - val_loss: 1.9299 - val_accuracy: 0.0215
# Epoch 2279/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3136 - accuracy: 0.1511 - val_loss: 1.9036 - val_accuracy: 0.0220
# Epoch 2280/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3112 - accuracy: 0.1530 - val_loss: 1.9191 - val_accuracy: 0.0207
# Epoch 2281/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3079 - accuracy: 0.1532 - val_loss: 1.9147 - val_accuracy: 0.0215
# Epoch 2282/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3076 - accuracy: 0.1513 - val_loss: 1.9141 - val_accuracy: 0.0207
# Epoch 2283/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3114 - accuracy: 0.1521 - val_loss: 1.9269 - val_accuracy: 0.0205
# Epoch 2284/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3110 - accuracy: 0.1511 - val_loss: 1.9225 - val_accuracy: 0.0210
# Epoch 2285/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3054 - accuracy: 0.1528 - val_loss: 1.9109 - val_accuracy: 0.0205
# Epoch 2286/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3081 - accuracy: 0.1511 - val_loss: 1.9074 - val_accuracy: 0.0213
# Epoch 2287/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3074 - accuracy: 0.1515 - val_loss: 1.9011 - val_accuracy: 0.0207
# Epoch 2288/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3041 - accuracy: 0.1529 - val_loss: 1.9110 - val_accuracy: 0.0213
# Epoch 2289/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3010 - accuracy: 0.1538 - val_loss: 1.9139 - val_accuracy: 0.0215
# Epoch 2290/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3007 - accuracy: 0.1538 - val_loss: 1.9268 - val_accuracy: 0.0215
# Epoch 2291/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3024 - accuracy: 0.1534 - val_loss: 1.9192 - val_accuracy: 0.0213
# Epoch 2292/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3032 - accuracy: 0.1531 - val_loss: 1.9234 - val_accuracy: 0.0207
# Epoch 2293/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2999 - accuracy: 0.1541 - val_loss: 1.9231 - val_accuracy: 0.0210
# Epoch 2294/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3099 - accuracy: 0.1524 - val_loss: 1.9088 - val_accuracy: 0.0210
# Epoch 2295/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3030 - accuracy: 0.1535 - val_loss: 1.9037 - val_accuracy: 0.0213
# Epoch 2296/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3018 - accuracy: 0.1548 - val_loss: 1.8899 - val_accuracy: 0.0215
# Epoch 2297/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3023 - accuracy: 0.1540 - val_loss: 1.9089 - val_accuracy: 0.0205
# Epoch 2298/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3043 - accuracy: 0.1536 - val_loss: 1.9130 - val_accuracy: 0.0205
# Epoch 2299/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3105 - accuracy: 0.1522 - val_loss: 1.9081 - val_accuracy: 0.0203
# Epoch 2300/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3088 - accuracy: 0.1531 - val_loss: 1.9074 - val_accuracy: 0.0205
# Epoch 2301/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3023 - accuracy: 0.1537 - val_loss: 1.9114 - val_accuracy: 0.0220
# Epoch 2302/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3049 - accuracy: 0.1539 - val_loss: 1.9185 - val_accuracy: 0.0205
# Epoch 2303/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3038 - accuracy: 0.1527 - val_loss: 1.9012 - val_accuracy: 0.0217
# Epoch 2304/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3106 - accuracy: 0.1512 - val_loss: 1.9086 - val_accuracy: 0.0217
# Epoch 2305/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3069 - accuracy: 0.1516 - val_loss: 1.9178 - val_accuracy: 0.0223
# Epoch 2306/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3052 - accuracy: 0.1526 - val_loss: 1.9126 - val_accuracy: 0.0217
# Epoch 2307/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3019 - accuracy: 0.1529 - val_loss: 1.9174 - val_accuracy: 0.0210
# Epoch 2308/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3005 - accuracy: 0.1549 - val_loss: 1.9438 - val_accuracy: 0.0207
# Epoch 2309/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.3065 - accuracy: 0.1529 - val_loss: 1.9250 - val_accuracy: 0.0205
# Epoch 2310/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3066 - accuracy: 0.1522 - val_loss: 1.9132 - val_accuracy: 0.0200
# Epoch 2311/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3018 - accuracy: 0.1548 - val_loss: 1.9365 - val_accuracy: 0.0207
# Epoch 2312/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3016 - accuracy: 0.1546 - val_loss: 1.9076 - val_accuracy: 0.0207
# Epoch 2313/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3013 - accuracy: 0.1530 - val_loss: 1.9297 - val_accuracy: 0.0213
# Epoch 2314/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3036 - accuracy: 0.1514 - val_loss: 1.9122 - val_accuracy: 0.0210
# Epoch 2315/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.2982 - accuracy: 0.1536 - val_loss: 1.9157 - val_accuracy: 0.0207
# Epoch 2316/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.2987 - accuracy: 0.1542 - val_loss: 1.9239 - val_accuracy: 0.0213
# Epoch 2317/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3052 - accuracy: 0.1536 - val_loss: 1.9253 - val_accuracy: 0.0225
# Epoch 2318/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3046 - accuracy: 0.1528 - val_loss: 1.9209 - val_accuracy: 0.0215
# Epoch 2319/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3000 - accuracy: 0.1533 - val_loss: 1.9127 - val_accuracy: 0.0210
# Epoch 2320/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2991 - accuracy: 0.1533 - val_loss: 1.9165 - val_accuracy: 0.0213
# Epoch 2321/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2988 - accuracy: 0.1551 - val_loss: 1.9048 - val_accuracy: 0.0205
# Epoch 2322/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3006 - accuracy: 0.1545 - val_loss: 1.9080 - val_accuracy: 0.0203
# Epoch 2323/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2985 - accuracy: 0.1542 - val_loss: 1.9147 - val_accuracy: 0.0210
# Epoch 2324/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.2947 - accuracy: 0.1547 - val_loss: 1.9096 - val_accuracy: 0.0213
# Epoch 2325/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3041 - accuracy: 0.1526 - val_loss: 1.9317 - val_accuracy: 0.0195
# Epoch 2326/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3027 - accuracy: 0.1541 - val_loss: 1.9132 - val_accuracy: 0.0213
# Epoch 2327/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3048 - accuracy: 0.1521 - val_loss: 1.9138 - val_accuracy: 0.0210
# Epoch 2328/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.2938 - accuracy: 0.1559 - val_loss: 1.9182 - val_accuracy: 0.0207
# Epoch 2329/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2911 - accuracy: 0.1541 - val_loss: 1.9080 - val_accuracy: 0.0200
# Epoch 2330/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2974 - accuracy: 0.1527 - val_loss: 1.9172 - val_accuracy: 0.0203
# Epoch 2331/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2981 - accuracy: 0.1559 - val_loss: 1.9321 - val_accuracy: 0.0207
# Epoch 2332/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3081 - accuracy: 0.1519 - val_loss: 1.9022 - val_accuracy: 0.0210
# Epoch 2333/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2987 - accuracy: 0.1528 - val_loss: 1.9141 - val_accuracy: 0.0207
# Epoch 2334/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.2967 - accuracy: 0.1549 - val_loss: 1.9017 - val_accuracy: 0.0215
# Epoch 2335/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3002 - accuracy: 0.1534 - val_loss: 1.9256 - val_accuracy: 0.0213
# Epoch 2336/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3026 - accuracy: 0.1531 - val_loss: 1.9193 - val_accuracy: 0.0203
# Epoch 2337/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3001 - accuracy: 0.1538 - val_loss: 1.9299 - val_accuracy: 0.0215
# Epoch 2338/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3023 - accuracy: 0.1531 - val_loss: 1.9109 - val_accuracy: 0.0217
# Epoch 2339/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.2970 - accuracy: 0.1551 - val_loss: 1.9135 - val_accuracy: 0.0207
# Epoch 2340/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.2968 - accuracy: 0.1544 - val_loss: 1.9133 - val_accuracy: 0.0207
# Epoch 2341/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3008 - accuracy: 0.1538 - val_loss: 1.9159 - val_accuracy: 0.0215
# Epoch 2342/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3009 - accuracy: 0.1561 - val_loss: 1.9187 - val_accuracy: 0.0205
# Epoch 2343/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3014 - accuracy: 0.1543 - val_loss: 1.9050 - val_accuracy: 0.0215
# Epoch 2344/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2941 - accuracy: 0.1571 - val_loss: 1.9086 - val_accuracy: 0.0210
# Epoch 2345/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2944 - accuracy: 0.1547 - val_loss: 1.9200 - val_accuracy: 0.0225
# Epoch 2346/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2962 - accuracy: 0.1547 - val_loss: 1.9095 - val_accuracy: 0.0205
# Epoch 2347/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2990 - accuracy: 0.1541 - val_loss: 1.9135 - val_accuracy: 0.0213
# Epoch 2348/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2952 - accuracy: 0.1553 - val_loss: 1.9024 - val_accuracy: 0.0213
# Epoch 2349/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2932 - accuracy: 0.1557 - val_loss: 1.9164 - val_accuracy: 0.0203
# Epoch 2350/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2914 - accuracy: 0.1555 - val_loss: 1.9168 - val_accuracy: 0.0223
# Epoch 2351/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2960 - accuracy: 0.1544 - val_loss: 1.9165 - val_accuracy: 0.0213
# Epoch 2352/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2940 - accuracy: 0.1537 - val_loss: 1.9256 - val_accuracy: 0.0213
# Epoch 2353/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2939 - accuracy: 0.1538 - val_loss: 1.8996 - val_accuracy: 0.0213
# Epoch 2354/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2965 - accuracy: 0.1541 - val_loss: 1.9226 - val_accuracy: 0.0200
# Epoch 2355/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2988 - accuracy: 0.1536 - val_loss: 1.9228 - val_accuracy: 0.0215
# Epoch 2356/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2969 - accuracy: 0.1536 - val_loss: 1.9187 - val_accuracy: 0.0200
# Epoch 2357/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2985 - accuracy: 0.1544 - val_loss: 1.9475 - val_accuracy: 0.0207
# Epoch 2358/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2950 - accuracy: 0.1554 - val_loss: 1.9155 - val_accuracy: 0.0213
# Epoch 2359/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2882 - accuracy: 0.1567 - val_loss: 1.9293 - val_accuracy: 0.0210
# Epoch 2360/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2892 - accuracy: 0.1559 - val_loss: 1.9108 - val_accuracy: 0.0215
# Epoch 2361/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2967 - accuracy: 0.1541 - val_loss: 1.9154 - val_accuracy: 0.0210
# Epoch 2362/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2936 - accuracy: 0.1559 - val_loss: 1.9322 - val_accuracy: 0.0207
# Epoch 2363/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2963 - accuracy: 0.1552 - val_loss: 1.9224 - val_accuracy: 0.0213
# Epoch 2364/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2939 - accuracy: 0.1540 - val_loss: 1.9127 - val_accuracy: 0.0213
# Epoch 2365/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2952 - accuracy: 0.1558 - val_loss: 1.9191 - val_accuracy: 0.0203
# Epoch 2366/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.2922 - accuracy: 0.1554 - val_loss: 1.9045 - val_accuracy: 0.0205
# Epoch 2367/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2980 - accuracy: 0.1557 - val_loss: 1.9237 - val_accuracy: 0.0200
# Epoch 2368/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2894 - accuracy: 0.1549 - val_loss: 1.8947 - val_accuracy: 0.0210
# Epoch 2369/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2970 - accuracy: 0.1536 - val_loss: 1.9057 - val_accuracy: 0.0220
# Epoch 2370/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2909 - accuracy: 0.1558 - val_loss: 1.9177 - val_accuracy: 0.0205
# Epoch 2371/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.2914 - accuracy: 0.1549 - val_loss: 1.9141 - val_accuracy: 0.0217
# Epoch 2372/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2948 - accuracy: 0.1548 - val_loss: 1.9061 - val_accuracy: 0.0210
# Epoch 2373/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2932 - accuracy: 0.1565 - val_loss: 1.9140 - val_accuracy: 0.0217
# Epoch 2374/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2879 - accuracy: 0.1572 - val_loss: 1.9296 - val_accuracy: 0.0205
# Epoch 2375/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2905 - accuracy: 0.1556 - val_loss: 1.9242 - val_accuracy: 0.0200
# Epoch 2376/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2939 - accuracy: 0.1559 - val_loss: 1.9008 - val_accuracy: 0.0207
# Epoch 2377/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2923 - accuracy: 0.1549 - val_loss: 1.9345 - val_accuracy: 0.0205
# Epoch 2378/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2975 - accuracy: 0.1556 - val_loss: 1.9270 - val_accuracy: 0.0210
# Epoch 2379/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2893 - accuracy: 0.1552 - val_loss: 1.9219 - val_accuracy: 0.0205
# Epoch 2380/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2977 - accuracy: 0.1539 - val_loss: 1.9218 - val_accuracy: 0.0205
# Epoch 2381/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2929 - accuracy: 0.1565 - val_loss: 1.9207 - val_accuracy: 0.0213
# Epoch 2382/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2956 - accuracy: 0.1551 - val_loss: 1.9318 - val_accuracy: 0.0210
# Epoch 2383/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.2918 - accuracy: 0.1565 - val_loss: 1.9272 - val_accuracy: 0.0210
# Epoch 2384/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2918 - accuracy: 0.1561 - val_loss: 1.9335 - val_accuracy: 0.0213
# Epoch 2385/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2944 - accuracy: 0.1553 - val_loss: 1.9197 - val_accuracy: 0.0210
# Epoch 2386/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2873 - accuracy: 0.1573 - val_loss: 1.9117 - val_accuracy: 0.0220
# Epoch 2387/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2943 - accuracy: 0.1548 - val_loss: 1.9086 - val_accuracy: 0.0210
# Epoch 2388/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2871 - accuracy: 0.1563 - val_loss: 1.9266 - val_accuracy: 0.0210
# Epoch 2389/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2897 - accuracy: 0.1577 - val_loss: 1.9315 - val_accuracy: 0.0207
# Epoch 2390/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2939 - accuracy: 0.1579 - val_loss: 1.9077 - val_accuracy: 0.0207
# Epoch 2391/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2895 - accuracy: 0.1569 - val_loss: 1.9103 - val_accuracy: 0.0210
# Epoch 2392/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2923 - accuracy: 0.1552 - val_loss: 1.9198 - val_accuracy: 0.0205
# Epoch 2393/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2944 - accuracy: 0.1558 - val_loss: 1.9158 - val_accuracy: 0.0205
# Epoch 2394/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2903 - accuracy: 0.1554 - val_loss: 1.9162 - val_accuracy: 0.0215
# Epoch 2395/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2844 - accuracy: 0.1559 - val_loss: 1.9229 - val_accuracy: 0.0213
# Epoch 2396/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2909 - accuracy: 0.1571 - val_loss: 1.9151 - val_accuracy: 0.0207
# Epoch 2397/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2917 - accuracy: 0.1554 - val_loss: 1.9010 - val_accuracy: 0.0220
# Epoch 2398/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2870 - accuracy: 0.1550 - val_loss: 1.9192 - val_accuracy: 0.0217
# Epoch 2399/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2900 - accuracy: 0.1573 - val_loss: 1.9074 - val_accuracy: 0.0205
# Epoch 2400/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2846 - accuracy: 0.1561 - val_loss: 1.9063 - val_accuracy: 0.0215
# Epoch 2401/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2864 - accuracy: 0.1567 - val_loss: 1.9309 - val_accuracy: 0.0213
# Epoch 2402/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2873 - accuracy: 0.1552 - val_loss: 1.9200 - val_accuracy: 0.0200
# Epoch 2403/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2906 - accuracy: 0.1559 - val_loss: 1.9138 - val_accuracy: 0.0215
# Epoch 2404/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2870 - accuracy: 0.1566 - val_loss: 1.9188 - val_accuracy: 0.0213
# Epoch 2405/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2933 - accuracy: 0.1541 - val_loss: 1.9290 - val_accuracy: 0.0210
# Epoch 2406/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2823 - accuracy: 0.1576 - val_loss: 1.9265 - val_accuracy: 0.0203
# Epoch 2407/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2838 - accuracy: 0.1557 - val_loss: 1.8985 - val_accuracy: 0.0227
# Epoch 2408/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2862 - accuracy: 0.1567 - val_loss: 1.9208 - val_accuracy: 0.0215
# Epoch 2409/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2888 - accuracy: 0.1559 - val_loss: 1.9014 - val_accuracy: 0.0217
# Epoch 2410/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2839 - accuracy: 0.1571 - val_loss: 1.9199 - val_accuracy: 0.0210
# Epoch 2411/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2875 - accuracy: 0.1562 - val_loss: 1.9091 - val_accuracy: 0.0225
# Epoch 2412/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2777 - accuracy: 0.1586 - val_loss: 1.9177 - val_accuracy: 0.0210
# Epoch 2413/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2926 - accuracy: 0.1558 - val_loss: 1.9186 - val_accuracy: 0.0220
# Epoch 2414/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2841 - accuracy: 0.1559 - val_loss: 1.9286 - val_accuracy: 0.0207
# Epoch 2415/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2842 - accuracy: 0.1573 - val_loss: 1.9099 - val_accuracy: 0.0207
# Epoch 2416/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.2907 - accuracy: 0.1564 - val_loss: 1.9154 - val_accuracy: 0.0210
# Epoch 2417/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2842 - accuracy: 0.1574 - val_loss: 1.9186 - val_accuracy: 0.0215
# Epoch 2418/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2912 - accuracy: 0.1548 - val_loss: 1.9074 - val_accuracy: 0.0220
# Epoch 2419/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2844 - accuracy: 0.1570 - val_loss: 1.9015 - val_accuracy: 0.0217
# Epoch 2420/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2837 - accuracy: 0.1565 - val_loss: 1.9131 - val_accuracy: 0.0215
# Epoch 2421/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.2868 - accuracy: 0.1558 - val_loss: 1.9061 - val_accuracy: 0.0210
# Epoch 2422/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2850 - accuracy: 0.1562 - val_loss: 1.9223 - val_accuracy: 0.0195
# Epoch 2423/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2796 - accuracy: 0.1569 - val_loss: 1.9143 - val_accuracy: 0.0217
# Epoch 2424/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2893 - accuracy: 0.1561 - val_loss: 1.9225 - val_accuracy: 0.0223
# Epoch 2425/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2929 - accuracy: 0.1555 - val_loss: 1.9119 - val_accuracy: 0.0200
# Epoch 2426/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2816 - accuracy: 0.1559 - val_loss: 1.9041 - val_accuracy: 0.0213
# Epoch 2427/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2870 - accuracy: 0.1572 - val_loss: 1.9108 - val_accuracy: 0.0213
# Epoch 2428/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2867 - accuracy: 0.1562 - val_loss: 1.9059 - val_accuracy: 0.0217
# Epoch 2429/4600
# ...
# Epoch 4492/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0968 - accuracy: 0.1951 - val_loss: 1.9212 - val_accuracy: 0.0115
# Epoch 4493/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0938 - accuracy: 0.1953 - val_loss: 1.9219 - val_accuracy: 0.0108
# Epoch 4494/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0970 - accuracy: 0.1953 - val_loss: 1.9231 - val_accuracy: 0.0110
# Epoch 4495/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0986 - accuracy: 0.1948 - val_loss: 1.9077 - val_accuracy: 0.0120
# Epoch 4496/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0945 - accuracy: 0.1953 - val_loss: 1.9151 - val_accuracy: 0.0110
# Epoch 4497/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0959 - accuracy: 0.1953 - val_loss: 1.9290 - val_accuracy: 0.0127
# Epoch 4498/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0978 - accuracy: 0.1954 - val_loss: 1.9355 - val_accuracy: 0.0113
# Epoch 4499/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0937 - accuracy: 0.1968 - val_loss: 1.9063 - val_accuracy: 0.0110
# Epoch 4500/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1026 - accuracy: 0.1934 - val_loss: 1.9259 - val_accuracy: 0.0105
# Epoch 4501/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0991 - accuracy: 0.1951 - val_loss: 1.9494 - val_accuracy: 0.0117
# Epoch 4502/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1074 - accuracy: 0.1924 - val_loss: 1.9339 - val_accuracy: 0.0115
# Epoch 4503/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1043 - accuracy: 0.1946 - val_loss: 1.9173 - val_accuracy: 0.0110
# Epoch 4504/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0955 - accuracy: 0.1959 - val_loss: 1.9151 - val_accuracy: 0.0105
# Epoch 4505/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0927 - accuracy: 0.1964 - val_loss: 1.9312 - val_accuracy: 0.0103
# Epoch 4506/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0932 - accuracy: 0.1954 - val_loss: 1.9473 - val_accuracy: 0.0103
# Epoch 4507/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.1005 - accuracy: 0.1941 - val_loss: 1.9179 - val_accuracy: 0.0110
# Epoch 4508/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0996 - accuracy: 0.1950 - val_loss: 1.9313 - val_accuracy: 0.0110
# Epoch 4509/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0982 - accuracy: 0.1951 - val_loss: 1.9488 - val_accuracy: 0.0110
# Epoch 4510/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0949 - accuracy: 0.1944 - val_loss: 1.9517 - val_accuracy: 0.0095
# Epoch 4511/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0922 - accuracy: 0.1967 - val_loss: 1.9406 - val_accuracy: 0.0120
# Epoch 4512/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0931 - accuracy: 0.1956 - val_loss: 1.9634 - val_accuracy: 0.0122
# Epoch 4513/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0938 - accuracy: 0.1952 - val_loss: 1.9329 - val_accuracy: 0.0120
# Epoch 4514/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1014 - accuracy: 0.1946 - val_loss: 1.9235 - val_accuracy: 0.0098
# Epoch 4515/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1119 - accuracy: 0.1934 - val_loss: 1.9166 - val_accuracy: 0.0117
# Epoch 4516/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1180 - accuracy: 0.1897 - val_loss: 1.9291 - val_accuracy: 0.0117
# Epoch 4517/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.1066 - accuracy: 0.1951 - val_loss: 1.9463 - val_accuracy: 0.0108
# Epoch 4518/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.1042 - accuracy: 0.1936 - val_loss: 1.9130 - val_accuracy: 0.0098
# Epoch 4519/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.1037 - accuracy: 0.1946 - val_loss: 1.9148 - val_accuracy: 0.0103
# Epoch 4520/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1089 - accuracy: 0.1937 - val_loss: 1.9294 - val_accuracy: 0.0110
# Epoch 4521/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1008 - accuracy: 0.1949 - val_loss: 1.9355 - val_accuracy: 0.0105
# Epoch 4522/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.1079 - accuracy: 0.1937 - val_loss: 1.9327 - val_accuracy: 0.0108
# Epoch 4523/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1097 - accuracy: 0.1929 - val_loss: 1.9376 - val_accuracy: 0.0127
# Epoch 4524/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1047 - accuracy: 0.1956 - val_loss: 1.9291 - val_accuracy: 0.0120
# Epoch 4525/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.1029 - accuracy: 0.1945 - val_loss: 1.9272 - val_accuracy: 0.0110
# Epoch 4526/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.1087 - accuracy: 0.1926 - val_loss: 1.9284 - val_accuracy: 0.0122
# Epoch 4527/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1035 - accuracy: 0.1943 - val_loss: 1.9437 - val_accuracy: 0.0110
# Epoch 4528/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.1020 - accuracy: 0.1941 - val_loss: 1.9196 - val_accuracy: 0.0137
# Epoch 4529/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0998 - accuracy: 0.1946 - val_loss: 1.9376 - val_accuracy: 0.0122
# Epoch 4530/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0973 - accuracy: 0.1939 - val_loss: 1.9272 - val_accuracy: 0.0105
# Epoch 4531/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0952 - accuracy: 0.1959 - val_loss: 1.9591 - val_accuracy: 0.0115
# Epoch 4532/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0940 - accuracy: 0.1950 - val_loss: 1.9232 - val_accuracy: 0.0110
# Epoch 4533/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1065 - accuracy: 0.1941 - val_loss: 1.9615 - val_accuracy: 0.0108
# Epoch 4534/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0962 - accuracy: 0.1943 - val_loss: 1.9492 - val_accuracy: 0.0098
# Epoch 4535/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0960 - accuracy: 0.1961 - val_loss: 1.9162 - val_accuracy: 0.0098
# Epoch 4536/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1003 - accuracy: 0.1948 - val_loss: 1.9280 - val_accuracy: 0.0093
# Epoch 4537/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0939 - accuracy: 0.1966 - val_loss: 1.9236 - val_accuracy: 0.0098
# Epoch 4538/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0956 - accuracy: 0.1956 - val_loss: 1.9385 - val_accuracy: 0.0105
# Epoch 4539/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1027 - accuracy: 0.1943 - val_loss: 1.9318 - val_accuracy: 0.0105
# Epoch 4540/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1052 - accuracy: 0.1936 - val_loss: 1.9542 - val_accuracy: 0.0108
# Epoch 4541/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1118 - accuracy: 0.1933 - val_loss: 1.9232 - val_accuracy: 0.0113
# Epoch 4542/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1096 - accuracy: 0.1922 - val_loss: 1.9333 - val_accuracy: 0.0108
# Epoch 4543/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1069 - accuracy: 0.1923 - val_loss: 1.9194 - val_accuracy: 0.0105
# Epoch 4544/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.1006 - accuracy: 0.1946 - val_loss: 1.9171 - val_accuracy: 0.0103
# Epoch 4545/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.1042 - accuracy: 0.1944 - val_loss: 1.9427 - val_accuracy: 0.0115
# Epoch 4546/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1016 - accuracy: 0.1939 - val_loss: 1.9448 - val_accuracy: 0.0115
# Epoch 4547/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0987 - accuracy: 0.1950 - val_loss: 1.9274 - val_accuracy: 0.0113
# Epoch 4548/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1016 - accuracy: 0.1942 - val_loss: 1.9713 - val_accuracy: 0.0113
# Epoch 4549/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.1035 - accuracy: 0.1941 - val_loss: 1.9269 - val_accuracy: 0.0085
# Epoch 4550/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1072 - accuracy: 0.1927 - val_loss: 1.9214 - val_accuracy: 0.0105
# Epoch 4551/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0971 - accuracy: 0.1951 - val_loss: 1.9400 - val_accuracy: 0.0098
# Epoch 4552/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1018 - accuracy: 0.1951 - val_loss: 1.9789 - val_accuracy: 0.0120
# Epoch 4553/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1029 - accuracy: 0.1935 - val_loss: 1.9890 - val_accuracy: 0.0125
# Epoch 4554/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0983 - accuracy: 0.1941 - val_loss: 1.9868 - val_accuracy: 0.0115
# Epoch 4555/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0912 - accuracy: 0.1963 - val_loss: 1.9731 - val_accuracy: 0.0115
# Epoch 4556/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0915 - accuracy: 0.1963 - val_loss: 1.9802 - val_accuracy: 0.0110
# Epoch 4557/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0941 - accuracy: 0.1959 - val_loss: 1.9441 - val_accuracy: 0.0108
# Epoch 4558/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1033 - accuracy: 0.1937 - val_loss: 1.9465 - val_accuracy: 0.0127
# Epoch 4559/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0944 - accuracy: 0.1963 - val_loss: 1.9130 - val_accuracy: 0.0113
# Epoch 4560/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0978 - accuracy: 0.1945 - val_loss: 1.9398 - val_accuracy: 0.0117
# Epoch 4561/4600
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0957 - accuracy: 0.1962 - val_loss: 1.9412 - val_accuracy: 0.0137
# Epoch 4562/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0980 - accuracy: 0.1961 - val_loss: 1.9270 - val_accuracy: 0.0125
# Epoch 4563/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1014 - accuracy: 0.1939 - val_loss: 1.9145 - val_accuracy: 0.0113
# Epoch 4564/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1020 - accuracy: 0.1942 - val_loss: 1.9253 - val_accuracy: 0.0113
# Epoch 4565/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0962 - accuracy: 0.1941 - val_loss: 1.9212 - val_accuracy: 0.0117
# Epoch 4566/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0883 - accuracy: 0.1971 - val_loss: 1.9341 - val_accuracy: 0.0117
# Epoch 4567/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0946 - accuracy: 0.1960 - val_loss: 1.9180 - val_accuracy: 0.0100
# Epoch 4568/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0920 - accuracy: 0.1959 - val_loss: 1.9384 - val_accuracy: 0.0100
# Epoch 4569/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0942 - accuracy: 0.1959 - val_loss: 1.9285 - val_accuracy: 0.0095
# Epoch 4570/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0933 - accuracy: 0.1969 - val_loss: 1.9376 - val_accuracy: 0.0098
# Epoch 4571/4600
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0900 - accuracy: 0.1964 - val_loss: 1.9440 - val_accuracy: 0.0103
# Epoch 4572/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0942 - accuracy: 0.1949 - val_loss: 1.9216 - val_accuracy: 0.0120
# Epoch 4573/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1024 - accuracy: 0.1944 - val_loss: 1.9324 - val_accuracy: 0.0117
# Epoch 4574/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1041 - accuracy: 0.1949 - val_loss: 1.9317 - val_accuracy: 0.0110
# Epoch 4575/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1030 - accuracy: 0.1953 - val_loss: 1.9428 - val_accuracy: 0.0135
# Epoch 4576/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1126 - accuracy: 0.1930 - val_loss: 1.9197 - val_accuracy: 0.0127
# Epoch 4577/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0994 - accuracy: 0.1953 - val_loss: 1.9422 - val_accuracy: 0.0125
# Epoch 4578/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1031 - accuracy: 0.1953 - val_loss: 1.9265 - val_accuracy: 0.0122
# Epoch 4579/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1045 - accuracy: 0.1944 - val_loss: 1.9398 - val_accuracy: 0.0120
# Epoch 4580/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1060 - accuracy: 0.1949 - val_loss: 1.9077 - val_accuracy: 0.0105
# Epoch 4581/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1011 - accuracy: 0.1956 - val_loss: 1.9343 - val_accuracy: 0.0115
# Epoch 4582/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0985 - accuracy: 0.1962 - val_loss: 1.9534 - val_accuracy: 0.0137
# Epoch 4583/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1030 - accuracy: 0.1949 - val_loss: 1.9160 - val_accuracy: 0.0117
# Epoch 4584/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1061 - accuracy: 0.1940 - val_loss: 1.9546 - val_accuracy: 0.0120
# Epoch 4585/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1126 - accuracy: 0.1926 - val_loss: 1.9385 - val_accuracy: 0.0117
# Epoch 4586/4600
# 32/32 [==============================] - 1s 21ms/step - loss: 0.1025 - accuracy: 0.1936 - val_loss: 1.9376 - val_accuracy: 0.0122
# Epoch 4587/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0993 - accuracy: 0.1955 - val_loss: 1.9193 - val_accuracy: 0.0122
# Epoch 4588/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0967 - accuracy: 0.1963 - val_loss: 1.9453 - val_accuracy: 0.0110
# Epoch 4589/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0938 - accuracy: 0.1970 - val_loss: 1.9357 - val_accuracy: 0.0108
# Epoch 4590/4600
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1004 - accuracy: 0.1948 - val_loss: 1.9478 - val_accuracy: 0.0122
# Epoch 4591/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0952 - accuracy: 0.1949 - val_loss: 1.9554 - val_accuracy: 0.0120
# Epoch 4592/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0979 - accuracy: 0.1954 - val_loss: 1.9474 - val_accuracy: 0.0105
# Epoch 4593/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0906 - accuracy: 0.1965 - val_loss: 1.9373 - val_accuracy: 0.0125
# Epoch 4594/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0950 - accuracy: 0.1937 - val_loss: 1.9498 - val_accuracy: 0.0110
# Epoch 4595/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0935 - accuracy: 0.1964 - val_loss: 1.9273 - val_accuracy: 0.0108
# Epoch 4596/4600
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1008 - accuracy: 0.1940 - val_loss: 1.9296 - val_accuracy: 0.0100
# Epoch 4597/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1011 - accuracy: 0.1933 - val_loss: 1.9593 - val_accuracy: 0.0127
# Epoch 4598/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1161 - accuracy: 0.1914 - val_loss: 1.9371 - val_accuracy: 0.0127
# Epoch 4599/4600
# 32/32 [==============================] - 1s 22ms/step - loss: 0.1019 - accuracy: 0.1924 - val_loss: 1.9311 - val_accuracy: 0.0120
# Epoch 4600/4600
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1118 - accuracy: 0.1916 - val_loss: 1.9183 - val_accuracy: 0.0127

# %%
# Import modules
from tensorflow import keras
from keras.layers import Input, LSTM, Dense, Dropout
from keras.models import Model, load_model
import numpy as np

# Loading the model that was trained in the previous step
training_model = load_model('training_model.h5')

# Keras inference setup from https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html
# Construct the encoder
# Getting the first input layer of the model
encoder_inputs = training_model.input[0]
# Getting the output of the encoder LSTM layer
encoder_outputs, state_h_enc, state_c_enc = training_model.layers[2].output
# Creating a list of the hidden and cell states of the encoder
encoder_states = [state_h_enc, state_c_enc]
# Creating a new model that takes the encoder inputs and outputs the encoder states
encoder_model = Model(encoder_inputs, encoder_states)

# Number of dimensions of the hidden state of the LSTM.
latent_dim = 256
# Creating a new input layer for the decoder model.
decoder_state_input_hidden = Input(shape=(latent_dim,))
decoder_state_input_cell = Input(shape=(latent_dim,))
# Creating a list of the hidden and cell states of the decoder
decoder_states_inputs = [decoder_state_input_hidden, decoder_state_input_cell]
# Passing the decoder inputs and the initial state of the decoder to the decoder LSTM layer
decoder_outputs, state_hidden, state_cell = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
# Creating a list of the hidden and cell states of the decoder
decoder_states = [state_hidden, state_cell]
# Regularization technique that prevents overfitting
dropout = Dropout(rate=0.5)
# Passing the output of the decoder LSTM layer to the decoder dense layer
decoder_outputs = decoder_dense(decoder_outputs)
# Decoder model
# Creating a new model that takes the decoder inputs and the initial state of the decoder as inputs
# and outputs the output of the decoder LSTM layer and the hidden and cell states of the decoder
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# Implementing the inference loop
def decode_sequence(test_input):
  # Encode the input as state vectors.
  states_value = encoder_model.predict(test_input)

  # Generate empty target sequence of length 1.
  target_seq = np.zeros((1, 1, num_decoder_characters))
  # Populate the first token of target sequence with the start token.
  target_seq[0, 0, target_features_index['<START>']] = 1.

  # Sampling loop for a batch of sequences
  # (to simplify, here we assume a batch of size 1).
  decoded_sentence = ''

  stop_condition = False
  while not stop_condition:
    # Run the decoder model to get possible 
    # output tokens (with probabilities) & states
    output_tokens, hidden_state, cell_state = decoder_model.predict(
      [target_seq] + states_value)

    # Choose token with highest probability
    sampled_token_index = np.argmax(output_tokens[0, -1, :])
    sampled_char = reverse_target_features_index[sampled_token_index]
    decoded_sentence += " " + sampled_char

    # Exit condition: either hit max length
    # or find stop token.
    if (sampled_char == '<END>' or len(decoded_sentence) > max_decoder_seq_length):
      stop_condition = True

    # Update the target sequence (of length 1).
    target_seq = np.zeros((1, 1, num_decoder_characters))
    target_seq[0, 0, sampled_token_index] = 1.

    # Update states
    states_value = [hidden_state, cell_state]

  return decoded_sentence

# %%
# !pip install discord
# Out:
# Collecting discord
#   Downloading discord-1.7.3-py3-none-any.whl (1.1 kB)
# Collecting discord.py>=1.7.3
#   Downloading discord.py-1.7.3-py3-none-any.whl (786 kB)
#      |████████████████████████████████| 786 kB 31.1 MB/s
# Collecting aiohttp<3.8.0,>=3.6.0
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 66.6 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 76.6 MB/s
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8.0,>=3.6.0->discord.py>=1.7.3->discord) (4.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.4 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8.0,>=3.6.0->discord.py>=1.7.3->discord) (21.4.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8.0,>=3.6.0->discord.py>=1.7.3->discord) (3.0.4)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp<3.8.0,>=3.6.0->discord.py>=1.7.3->discord) (2.10)
# Installing collected packages: multidict, yarl, async-timeout, aiohttp, discord.py, discord
# Successfully installed aiohttp-3.7.4.post0 async-timeout-3.0.1 discord-1.7.3 discord.py-1.7.3 multidict-6.0.2 yarl-1.7.2

# %%
# Import modules
import nest_asyncio
nest_asyncio.apply()
import numpy as np
import re
import discord

# Creating a class that contains the discord method for running the chatbot
class ChatBot(discord.Client):

  # Function from https://www.codecademy.com/learn/deep-learning-and-generative-chatbots/modules/generative-chatbots/cheatsheet
  # Converts user input into a matrix  
  def convert_to_matrix(self, user_input):
    # Splitting the user input into tokens
    tokens = re.findall(r"[\w']+|[^\s\w]", user_input)
    # Creating a matrix of zeros with the dimensions of 1, max_encoder_seq_length, and
    # num_encoder_characters
    user_input_matrix = np.zeros((1, max_encoder_seq_length, num_encoder_characters), dtype = 'float32')
    # Converting the user input into a matrix
    for timestep, token in enumerate(tokens):
      if token in input_features_index:
        user_input_matrix[0, timestep, input_features_index[token]] = 1.0
    return user_input_matrix
  
  # Creating a response using the seq2seq model
  # Body copied from decode_sequence in test.py but uses user input this time
  def generate_response(self, user_input):
    # Gets user input and convert it to matrix
    input_matrix = self.convert_to_matrix(user_input)
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_matrix)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_characters))
     # Populate the first token of target sequence with the start token.
    target_seq[0, 0, target_features_index['<START>']] = 1.0
    # Sampling loop for a batch of sequences
    # # (to simplify, here we assume a batch of size 1).
    chatbot_response = ''

    stop_condition = False
    while not stop_condition:
      # Run the decoder model to get possible 
      # # output tokens (with probabilities) & states
      output_tokens, hidden_state, cell_state = decoder_model.predict(
        [target_seq] + states_value)
      
      # Choose token with highest probability
      sampled_token_index = np.argmax(output_tokens[0, -1, :])
      sampled_char = reverse_target_features_index[sampled_token_index]
      chatbot_response += " " + sampled_char
      
      # Exit condition: either hit max length
      # # or find stop token.
      if (sampled_char == '<END>' or len(chatbot_response) > max_decoder_seq_length):
        stop_condition = True

      # Update the target sequence (of length 1).  
      target_seq = np.zeros((1, 1, num_decoder_characters))
      target_seq[0, 0, sampled_token_index] = 1.0
      
      # Update states
      states_value = [hidden_state, cell_state]
    
    # Sets response by marking the start and end of each sentence 
    chatbot_response = chatbot_response.replace("<START>", "").replace("<END>", "")

    # Returns response  
    return chatbot_response + "\n"

  async def on_ready(self):
        # Prints out information when the bot wakes up
        print('Logged in as')
        print(self.user.name)
        print(self.user.id)
        print('------')

  # Sending and receiving messages      
  async def on_message(self, message):
    if message.author.id == self.user.id:
            return
    
    # Waiting for a user reply:
    user_input = message.content
    if user_input.startswith("$"):
        await message.channel.send(self.generate_response(user_input))

# Client running
def main():
  DiscordChatbot = ChatBot()
  DiscordChatbot.run("OTEzNDcwODAwNzYwMjkxMzc4.YZ-9-g.6Mit3B2mC4WtkQ8DZnlWqrK7OLg")

if __name__ == '__main__':
  main()
# Out:
# Logged in as
# PrototypeBot
# 913470800760291378
# ------
